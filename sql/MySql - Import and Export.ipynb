# %% [markdown]
# # Import data to My SQL from Csv

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import os

# %%
file_path = 'E:\analytics\data\students2.csv'
print(file_path)
# Out:
# E:nalytics\data\students2.csv

# %%
file_path = 'C:\analytics\data\students2.csv'
print(file_path)
# Out:
# C:nalytics\data\students2.csv

# %%
df = pd.read_csv(file_path)
df.shape
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_csv(file_path)
#       2 df.shape
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
file_path = 'E:\analytics\data\students2.csv'
print(file_path)
# Out:
# E:nalytics\data\students2.csv

# %%
file_path = 'E:/analytics/data/students2.csv'
print(file_path)
# Out:
# E:/analytics/data/students2.csv

# %%
df = pd.read_csv(file_path)
df.shape
# Out:
# (30, 6)

# %%
df.head()
# Out:
#    rollno      name  gender         dob  height program
# 0       1  Jugurtha    Male  2000-08-16     156     BCA
# 1       2  Amandeep  Female  2000-02-21     170     BBA
# 2       3    Barkat  Female  2001-07-17     158     BCA
# 3       4    Suroor  Female  2001-11-16     188     BBA
# 4       5   Sultana    Male  2001-04-02     167     BCA

# %%
engine1=create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")
engine1
# Out:
# Engine(mysql+pymysql://piuser:***@localhost:3306/piit)

# %%
df.to_sql('students2', engine1, if_exists='append', index=False, chunksize=1000, method='multi')
# Out:
# 30

# %%
df2 = pd.read_sql("SELECT * FROM students2;", engine1)
df2.head()
# Out:
#    rollno      name  gender         dob  height program
# 0       1  Jugurtha    Male  2000-08-16     156     BCA
# 1       2  Amandeep  Female  2000-02-21     170     BBA
# 2       3    Barkat  Female  2001-07-17     158     BCA
# 3       4    Suroor  Female  2001-11-16     188     BBA
# 4       5   Sultana    Male  2001-04-02     167     BCA

# %%
df2.to_csv('E:/analytics/data/students3.csv')

# %%
df2.to_excel('E:/analytics/data/students4.xlsx')

# %%
print(sorted(os.listdir('E:/analytics/data'), key=str.lower))
# Out:
# ['employees.csv', 'mtcarsdata.csv', 'students2.csv', 'students3.csv', 'students3.xlsx', 'students4.xlsx']

# %%
df2a = pd.read_csv('E:/analytics/data/students3.csv')
df2a.shape
# Out:
# (90, 7)

# %%
csvfile = 'E:/analytics/data/students3.csv'
xlsfile =  'E:/analytics/data/students4.xlsx'

# %%
df2.to_csv(csvfile, index=False)

# %%
df2.to_excel(xlsfile, index=False)

# %%
df2b = pd.read_csv(csvfile)
df2b.shape
# Out:
# (90, 6)

# %%
df2c = pd.read_excel(xlsfile)
df2c.shape
# Out:
# (90, 6)

# %%
df2b
# Out:
#     rollno        name  gender         dob  height program
# 0        1    Jugurtha    Male  2000-08-16     156     BCA
# 1        2    Amandeep  Female  2000-02-21     170     BBA
# 2        3      Barkat  Female  2001-07-17     158     BCA
# 3        4      Suroor  Female  2001-11-16     188     BBA
# 4        5     Sultana    Male  2001-04-02     167     BCA
# ..     ...         ...     ...         ...     ...     ...
# 85      26  Student_26     NaN  2001-07-23     167     BBA
# 86      27  Student_27    Male  2000-11-14     175     BBA
# 87      28  Student_28  Female  2001-03-16     183     BBA
# 88      29  Student_29  Female  2001-11-20     159     BBA
# 89      30  Student_30    Male  2000-07-28     185     BBA
#
# [90 rows x 6 columns]

# %%
df4 = df2b.copy()
df4
# Out:
#     rollno        name  gender         dob  height program
# 0        1    Jugurtha    Male  2000-08-16     156     BCA
# 1        2    Amandeep  Female  2000-02-21     170     BBA
# 2        3      Barkat  Female  2001-07-17     158     BCA
# 3        4      Suroor  Female  2001-11-16     188     BBA
# 4        5     Sultana    Male  2001-04-02     167     BCA
# ..     ...         ...     ...         ...     ...     ...
# 85      26  Student_26     NaN  2001-07-23     167     BBA
# 86      27  Student_27    Male  2000-11-14     175     BBA
# 87      28  Student_28  Female  2001-03-16     183     BBA
# 88      29  Student_29  Female  2001-11-20     159     BBA
# 89      30  Student_30    Male  2000-07-28     185     BBA
#
# [90 rows x 6 columns]

# %%
df5 = pd.read_csv('E:/analytics/data/employees.csv')
df5.shape
# Out:
# (20, 1)

# %%
df6 = df5.copy()
df6
# Out:
#    employee_id;"first_name";"last_name";"department";"salary"
# 0                         1;"John";"Doe";"HR";50000.0
# 1                       2;"Jane";"Smith";"IT";60000.0
# 2               3;"Alice";"Johnson";"Finance";55000.0
# 3                     4;"Bob";"Williams";"IT";62000.0
# 4                      5;"Emily";"Brown";"HR";48000.0
# 5               6;"Michael";"Davis";"Finance";57000.0
# 6                    7;"Sophia";"Wilson";"IT";61000.0
# 7              8;"David";"Miller";"Marketing";53000.0
# 8                    9;"Olivia";"Taylor";"HR";49000.0
# 9             10;"James";"Anderson";"Finance";59000.0
# 10                      101;"John";"Doe";"HR";50000.0
# 11                    102;"Jane";"Smith";"IT";60000.0
# 12            103;"Alice";"Johnson";"Finance";55000.0
# 13                  104;"Bob";"Williams";"IT";62000.0
# 14                   105;"Emily";"Brown";"HR";48000.0
# 15            106;"Michael";"Davis";"Finance";57000.0
# ...

# %%
df6['employee_id'] = df6['employee_id']+200
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'employee_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 df6['employee_id'] = df6['employee_id']+200
#
# ...

# %%
df5 = pd.read_csv('E:/analytics/data/employees.csv', sep=';')
df5.shape
# Out:
# (20, 5)

# %%
print(df5.columns)
# Out:
# Index(['employee_id', 'first_name', 'last_name', 'department', 'salary'], dtype='object')

# %%
df6 = df5.copy()
df6
# Out:
#     employee_id first_name last_name department   salary
# 0             1       John       Doe         HR  50000.0
# 1             2       Jane     Smith         IT  60000.0
# 2             3      Alice   Johnson    Finance  55000.0
# 3             4        Bob  Williams         IT  62000.0
# 4             5      Emily     Brown         HR  48000.0
# 5             6    Michael     Davis    Finance  57000.0
# 6             7     Sophia    Wilson         IT  61000.0
# 7             8      David    Miller  Marketing  53000.0
# 8             9     Olivia    Taylor         HR  49000.0
# 9            10      James  Anderson    Finance  59000.0
# 10          101       John       Doe         HR  50000.0
# 11          102       Jane     Smith         IT  60000.0
# 12          103      Alice   Johnson    Finance  55000.0
# 13          104        Bob  Williams         IT  62000.0
# 14          105      Emily     Brown         HR  48000.0
# ...

# %%
df6['employee_id'] = df6['employee_id']+200

# %%
df6
# Out:
#     employee_id first_name last_name department   salary
# 0           201       John       Doe         HR  50000.0
# 1           202       Jane     Smith         IT  60000.0
# 2           203      Alice   Johnson    Finance  55000.0
# 3           204        Bob  Williams         IT  62000.0
# 4           205      Emily     Brown         HR  48000.0
# 5           206    Michael     Davis    Finance  57000.0
# 6           207     Sophia    Wilson         IT  61000.0
# 7           208      David    Miller  Marketing  53000.0
# 8           209     Olivia    Taylor         HR  49000.0
# 9           210      James  Anderson    Finance  59000.0
# 10          301       John       Doe         HR  50000.0
# 11          302       Jane     Smith         IT  60000.0
# 12          303      Alice   Johnson    Finance  55000.0
# 13          304        Bob  Williams         IT  62000.0
# 14          305      Emily     Brown         HR  48000.0
# ...

# %%
df6.tail()
# Out:
#     employee_id first_name last_name department   salary
# 15          306    Michael     Davis    Finance  57000.0
# 16          307     Sophia    Wilson         IT  61000.0
# 17          308      David    Miller  Marketing  53000.0
# 18          309     Olivia    Taylor         HR  49000.0
# 19          310      James  Anderson    Finance  59000.0

# %%
df6 = pd.read_sql("SELECT * FROM employees", engine1)
df6
# Out:
#    employee_id     name  department_id
# 0            1    Alice            1.0
# 1            2      Bob            2.0
# 2            3  Charlie            1.0
# 3            4    David            3.0
# 4            5      Eve            NaN

# %%
df4.to_sql(  name='employees',    con=engine1,   if_exists='append',   # options: 'fail', 'replace', 'append'
    index=False )
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1933, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1932     if not evt_handled:
# -> 1933         self.dialect.do_executemany(
#    1934             cursor,
#    1935             str_statement,
#    1936             effective_parameters,
#    1937             context,
#    1938         )
#    1939 elif not effective_parameters and context.no_parameters:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:172, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     171 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 172     rowcount = cursor.executemany(statement, parameters)
#     173     if context is not None:
#
# ...
